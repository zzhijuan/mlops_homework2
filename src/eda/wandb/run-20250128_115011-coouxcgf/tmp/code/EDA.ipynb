# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: zzhijuan (zzhijuan-university-of-houston). Use `wandb login --relogin` to force relogin
# wandb version 0.19.4 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/Users/zhijuanzhang/Documents/UdacityCourse/Homework2/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20250128_115011-coouxcgf</code>
# Syncing run <strong><a href='https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb/runs/coouxcgf' target="_blank">prime-surf-2</a></strong> to <a href='https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb' target="_blank">https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb/runs/coouxcgf' target="_blank">https://wandb.ai/zzhijuan-university-of-houston/nyc_airbnb/runs/coouxcgf</a>

# %%
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/IPython/core/formatters.py:770, in __call__(self, obj)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/IPython/lib/pretty.py:419, in pretty(self, obj)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/IPython/lib/pretty.py:794, in _repr_pprint(obj, p, cycle)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/pandas/core/frame.py:1133, in __repr__(self)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/pandas/core/frame.py:1310, in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/pandas/io/formats/format.py:1097, in to_string(self, buf, encoding, line_width)
#
# ModuleNotFoundError: No module named 'pandas.io.formats.string'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/IPython/core/formatters.py:406, in __call__(self, obj)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/pandas/core/frame.py:1175, in _repr_html_(self)
#
# File /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/pandas/io/formats/format.py:1060, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#
# ModuleNotFoundError: No module named 'pandas.io.formats.html'

# %%
# !pip install pandas-profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_widgets()
# Out:
# Summarize dataset:  10%| | 2/21 [00:00<00:04,  4.34it/s, Describe variable:hos
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lb/lzwyxcq94m1db_9xkvlzj29w0000gn/T/ipykernel_26812/598487227.py in ?()
#       1 from ydata_profiling import ProfileReport
#       2
#       3 profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
# ----> 4 profile.to_widgets()
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     296 'Could not get source, probably due dynamically evaluated source code.'
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/profile_report.py in ?(self)
#     260 'Could not get source, probably due dynamically evaluated source code.'
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/describe.py in ?(config, df, summarizer, typeset, sample)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/multimethod/__init__.py in ?(self, *args, **kwargs)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(config, df, summarizer, typeset, pbar)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/multiprocessing/pool.py in ?(self, timeout)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/multiprocessing/pool.py in ?(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(args)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/multimethod/__init__.py in ?(self, *args, **kwargs)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/pandas/summary_pandas.py in ?(config, series, summarizer, typeset)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/summarizer.py in ?(self, config, series, dtype)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(self, dtype, *args, **kwargs)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(*x)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(*x)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(*x)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/handler.py in ?(*x)
#      16 'Could not get source, probably due dynamically evaluated source code.'
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/multimethod/__init__.py in ?(self, *args, **kwargs)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(config, series, summary)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(config, series, summary)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/pandas/describe_categorical_pandas.py in ?(config, series, summary)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/ydata_profiling/model/summary_algorithms.py in ?(values, histogram)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(f_obs, f_exp, ddof, axis, sum_check)
#
# /opt/anaconda3/envs/mlflow-e4fcefd643ef1ee947cfeff48521954cf08a16aa/lib/python3.10/site-packages/scipy/stats/_stats_py.py in ?(f_obs, f_exp, ddof, axis, lambda_, sum_check)
#
# AttributeError: 'float' object has no attribute 'ndim'

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])
